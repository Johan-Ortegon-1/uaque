# %%
import sys

sys.path.append('./')

# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
from DataPrep import Material

# %%
preprMaterial = Material()

# %%
preprMaterial.clean()

# %%
from DataPrep import History

# %%
preprHistory = History()

# %%
preprHistory.clean()

# %%
from DataPrep import Merger

# %%
join = Merger(preprHistory.prestamosLimpio, preprMaterial.materialLimpio)

# %%
join.join()

# %%
join.df.columns
# Out:
# Index(['RowID', 'Fecha', 'IDItem', 'Llave', 'Programa', 'Facultad',
#        'IDUsuario', 'Year', 'Signatura', 'Autor', 'Titulo', 'AnioPublicacion',
#        'DeweyUnidad', 'DeweyDecena', 'DeweyCentena', 'NumeroUbicacion',
#        'Dewey', 'Ubicacion', 'TipoItem', 'FechaCreacion', 'DeweyEspecifico',
#        'TemaDewey', 'Temas', 'Union', 'Calificacion', 'Nivel'],
#       dtype='object')

# %%
join.df
# Out:
#             RowID                Fecha          IDItem   Llave  \
# 0            Row0  2019-01-09 16:14:57  80000005327627  866245
# 1            Row1  2019-01-09 16:15:00  80000001191496  309945
# 2            Row2  2019-01-10 16:46:03  80000004979759  822727
# 3            Row3  2019-01-10 16:46:05  80000004509512  784541
# 4            Row4  2019-01-12 13:37:49  80000005270756  858473
# ...           ...                  ...             ...     ...
# 489498   Row24847           1636509901  80000005577703  920778
# 489499  Row292916           1636509901  80000005556788  899375
# 489500  Row166961           1636509901  80000005577703  920778
# 489501  Row378809           1636509901  80000005576690  918801
# 489502   Row92415           1636735741  80000004156488  731232
#
#                                  Programa               Facultad  \
# 0                 CARRERA DE ARQUITECTURA  Arquitectura y Diseño
# 1                 CARRERA DE ARQUITECTURA  Arquitectura y Diseño
# ...
