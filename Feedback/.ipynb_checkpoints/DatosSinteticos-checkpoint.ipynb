# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_json('https://www.dropbox.com/s/upwvynmu0v5qh3p/joinCluster.json?dl=1')

# %%
df.head(3)
# Out:
#   RowID          Fecha          IDItem NumeroUbicacion Dewey   Ubicacion  \
# 0  Row0  1547050497000  80000005327627     720.98 A71S   720  COL-GRAL-2
# 1  Row1  1547050500000  80000001191496    720.9861 A71   720  COL-GRAL-2
# 2  Row2  1547138763000  80000004979759  540 CH15Q 2010   540  COL-GRAL-3
#
#     Llave                 Programa               Facultad  \
# 0  866245  CARRERA DE ARQUITECTURA  arquitectura y diseño
# 1  309945  CARRERA DE ARQUITECTURA  arquitectura y diseño
# 2  822727  CARRERA DE ARQUITECTURA  arquitectura y diseño
#
#                                   IDUsuario  ...  \
# 0  c361c772cd0220bb16dcfb2ad803e4903334ab94  ...
# 1  c361c772cd0220bb16dcfb2ad803e4903334ab94  ...
# 2  87b0e5a61ed712ddfaf5d478ad68c87c825997e9  ...
#
#                            Autor  \
# 0  Arango Cardinal, Silvia 1948-
# 1  Arango Cardinal, Silvia 1948-
# 2                 Chang, Raymond
#
#                                               Titulo AnioPublicacion  \
# 0  Ciudad y arquitectura seis generaciones que co...          2012.0
# 1  Historia de la arquitectura en Colombia Silvia...          1993.0
# 2  Química Raymond Chang ; revisión técnica Rosa ...          2010.0
#
#   DeweyEspecifico                     TemaDewey  \
# 0          720.98  Arquitectura latinoamericana
# 1        720.9861       Arquitectura colombiana
# 2             540                       Química
#
#                                        Temas  \
# 0        [arquitectur, histori, amer, latin]
# 1  [arquitectur, colonial, histori, colombi]
# 2                                   [quimic]
#
#                                   Union Peso_x Peso_y cluster
# 0        arquitectur histori amer latin   0.25   5.25       3
# 1  arquitectur colonial histori colombi   0.25   5.25       3
# 2                                quimic   0.25   5.50      37
#
# [3 rows x 23 columns]

# %% [markdown]
# Se creará un DataFrame el cual tendrá como columnas: IDUsuario, Fecha, Llave, Calificacion. Cada fila del dataframe representa una retroalimentación por parte del usuario cuando se realiza una recomendación. El usuario unicamente puede dicidir si le gustó o no la recomendación a través de botones de like y dislike por lo cual el atributo calificación solo tendrá dos valores. Si a el usuario le agrada la recomendación se da un valor de 1 si no -1. Esto con el fin de modificar los pesos que tienen los usuarios por dewey cuando se generan los clusters y en caso de que las recomendaciones no sean adecuadas cambiar al usuario de cluster.

# %%
calificaciones = pd.DataFrame(columns= ["IDUsuario", "Year", "IDItem", "Calificación"])
calificaciones
# Out:
# Empty DataFrame
# Columns: [IDUsuario, Year, IDItem, Calificación]
# Index: []

# %%
import random
def aleatorios(num):
    for i in range(num):
        id = random.choice(df.IDUsuario.unique())
        IDItem = random.choice(df.IDItem.unique())
        cal = random.choice([-1,1])
        anio = random.choice([2021])
        calificaciones.loc[i] = [id,anio,IDItem,cal]

# %%
aleatorios(100)

# %%
calificaciones
# Out:
#                                     IDUsuario  Year          IDItem  \
# 0    e51b417937525cf61917f889676c710e54acc20d  2021  60000000051338
# 1    e82f53bbb106687e7cdc221090f736436ebf31e4  2021  80000003195370
# 2    c7f75033020ddb2f8acb4eae22d51207ce63a72c  2021  80000003708831
# 3    fb542a12b1af50202070881929396087c9843ff7  2021  80000005408258
# 4    eba907893a3ff218a0c2311a145adea2ddd0a16a  2021  80000004906649
# ..                                        ...   ...             ...
# 995  23860998574bb3293cba20ce44feb09bab583515  2021  80000005269101
# 996  359b6b529a2f397682921dfe8bc25aaaefffae77  2021  80000004812346
# 997  39d26ebebc21f9f105a134b1e0c76cf1000616a7  2021  80000004318336
# 998  2c7c9877d97efb887d9ab1dfc986e6e61dae505a  2021  80000005557508
# 999  66a57a7300a156f62180c7f3dee7b9d85cbc600f  2021  80000005391376
#
#     Calificación
# 0             -1
# 1              1
# 2              1
# 3              1
# 4              1
# ..           ...
# 995            1
# 996            1
# 997            1
# 998           -1
# 999           -1
#
# [1000 rows x 4 columns]

# %%
def aleatorioCluster(num, cluster):
    sub = df.loc[df.cluster == cluster]
    for i in range(num):
        id = random.choice(sub.IDUsuario.unique())
        IDItem = random.choice(df.IDItem.unique())
        cal = random.choice([-1,1])
        anio = random.choice([2021])
        calificaciones.loc[i] = [id,anio,IDItem,cal]

# %%
aleatorioCluster(100,3)

# %%
def librosRelacionados(num, cluster):
    sub = df.loc[df.cluster == cluster]
    for i in range(num):
        id = random.choice(sub.IDUsuario.unique())
        IDItem = random.choice(sub.IDItem.unique())
        cal = random.choice([-1,1])
        anio = random.choice([2021])
        calificaciones.loc[i] = [id,anio,IDItem,cal]

# %%
librosRelacionados(1000,152)

# %%
def agregarUsuario(id, anio, IDItem, cal):
    i = calificaciones.shape[0]
    calificaciones.loc[i] = [id,anio,IDItem,cal]

# %%
agregarUsuario("fa31e19dc88b6af2b708328dac335c8ead738c1e", 2021, 80000005327627, -1)

# %% [markdown]
# Tras obtener las recomendaciones con los feedbacks que dan los usuarios podemos realizar un append a las tabla de prestamos.

# %%
datasetPrestamos = pd.read_json('https://www.dropbox.com/s/ez2uzrfwmvzpim8/PRESTAMOS-BGENERAL.json?dl=1')

# %%
datasetPrestamos.head(3)
# Out:
#   RowID    Mes          Fecha          IDItem NumeroUbicacion Dewey  \
# 0  Row0  Enero  1547050497000  80000005327627     720.98 A71S   720
# 1  Row1  Enero  1547050500000  80000001191496    720.9861 A71   720
# 2  Row2  Enero  1547138763000  80000004979759  540 CH15Q 2010   540
#
#     Ubicacion TipoItem   Llave      Perfil                 Programa  \
# 0  COL-GRAL-2    LIBRO  866245  A-EGRESADO  CARRERA DE ARQUITECTURA
# 1  COL-GRAL-2    LIBRO  309945  A-EGRESADO  CARRERA DE ARQUITECTURA
# 2  COL-GRAL-3    LIBRO  822727  A-EGRESADO  CARRERA DE ARQUITECTURA
#
#                 Facultad                                 IDUsuario  Year
# 0  arquitectura y diseño  c361c772cd0220bb16dcfb2ad803e4903334ab94  2019
# 1  arquitectura y diseño  c361c772cd0220bb16dcfb2ad803e4903334ab94  2019
# 2  arquitectura y diseño  87b0e5a61ed712ddfaf5d478ad68c87c825997e9  2019

# %%
datasetPrestamos = datasetPrestamos.append(calificaciones)

# %%
datasetPrestamos.reset_index(inplace=True)
datasetPrestamos
# Out:
#         index RowID    Mes         Fecha          IDItem NumeroUbicacion  \
# 0           0  Row0  Enero  1.547050e+12  80000005327627     720.98 A71S
# 1           1  Row1  Enero  1.547050e+12  80000001191496    720.9861 A71
# 2           2  Row2  Enero  1.547139e+12  80000004979759  540 CH15Q 2010
# 3           3  Row3  Enero  1.547139e+12  80000004509512        512 B151
# 4           4  Row4  Enero  1.547300e+12  80000005270756        712 M17E
# ...       ...   ...    ...           ...             ...             ...
# 490732    995   NaN    NaN           NaN  80000005269101             NaN
# 490733    996   NaN    NaN           NaN  80000004812346             NaN
# 490734    997   NaN    NaN           NaN  80000004318336             NaN
# 490735    998   NaN    NaN           NaN  80000005557508             NaN
# 490736    999   NaN    NaN           NaN  80000005391376             NaN
#
#        Dewey   Ubicacion TipoItem   Llave      Perfil  \
# 0        720  COL-GRAL-2    LIBRO  866245  A-EGRESADO
# 1        720  COL-GRAL-2    LIBRO  309945  A-EGRESADO
# 2        540  COL-GRAL-3    LIBRO  822727  A-EGRESADO
# 3        510  COL-GRAL-3    LIBRO  784541  A-EGRESADO
# 4        710  COL-GRAL-2    LIBRO  858473  A-EGRESADO
# ...      ...         ...      ...     ...         ...
# 490732   NaN         NaN      NaN     NaN         NaN
# 490733   NaN         NaN      NaN     NaN         NaN
# 490734   NaN         NaN      NaN     NaN         NaN
# 490735   NaN         NaN      NaN     NaN         NaN
# 490736   NaN         NaN      NaN     NaN         NaN
#
#                        Programa               Facultad  \
# 0       CARRERA DE ARQUITECTURA  arquitectura y diseño
# 1       CARRERA DE ARQUITECTURA  arquitectura y diseño
# 2       CARRERA DE ARQUITECTURA  arquitectura y diseño
# 3       CARRERA DE ARQUITECTURA  arquitectura y diseño
# 4       CARRERA DE ARQUITECTURA  arquitectura y diseño
# ...                         ...                    ...
# 490732                      NaN                    NaN
# 490733                      NaN                    NaN
# 490734                      NaN                    NaN
# 490735                      NaN                    NaN
# 490736                      NaN                    NaN
#
#                                        IDUsuario  Year Calificación
# 0       c361c772cd0220bb16dcfb2ad803e4903334ab94  2019          NaN
# 1       c361c772cd0220bb16dcfb2ad803e4903334ab94  2019          NaN
# 2       87b0e5a61ed712ddfaf5d478ad68c87c825997e9  2019          NaN
# 3       87b0e5a61ed712ddfaf5d478ad68c87c825997e9  2019          NaN
# 4       afe8c17ba351d274fc5671978918f0c93032d88f  2019          NaN
# ...                                          ...   ...          ...
# 490732  23860998574bb3293cba20ce44feb09bab583515  2021            1
# 490733  359b6b529a2f397682921dfe8bc25aaaefffae77  2021            1
# 490734  39d26ebebc21f9f105a134b1e0c76cf1000616a7  2021            1
# 490735  2c7c9877d97efb887d9ab1dfc986e6e61dae505a  2021           -1
# 490736  66a57a7300a156f62180c7f3dee7b9d85cbc600f  2021           -1
#
# [490737 rows x 16 columns]

# %%
datasetPrestamos.to_json (r'/Users/juansebastianangaritatorres/Downloads/PRESTAMOS-BGENERAL-FEEDBACK.json')

# %%
temporal = pd.read_json('https://www.dropbox.com/s/xjsjws8vgvs4m8k/userCluster.json?dl=1')

# %%
display(temporal["cluster"].value_counts().plot(kind='bar',figsize=(25,15)))
# Out:
# <AxesSubplot:>
